# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from g_keys import g_key
gmaps.configure(api_key=g_key)

# %%
P1_df = pd.read_csv("C:/Users/19739/Desktop/New folder/Project_4/Resources/FD_List.csv")
P1_df
# Out:
#                  Fire Department Name  Fire Department Code  \
# 0              ALBANY FIRE DEPARTMENT                  1001
# 1            ALTAMONT FIRE DEPARTMENT                  1002
# 2               BERNE FIRE DEPARTMENT                  1003
# 3     BOGHT COMMUNITY FIRE DEPARTMENT                  1004
# 4            COEYMANS FIRE DEPARTMENT                  1005
# ...                               ...                   ...
# 1768           HIMROD FIRE DEPARTMENT                 62006
# 1769           MIDDLESEX HOSE COMPANY                 62008
# 1770         PENN YAN FIRE DEPARTMENT                 62009
# 1771           POTTER FIRE DEPARTMENT                 62010
# 1772           RUSHVILLE HOSE COMPANY                 62011
#
#                          Address       City State    Zip Code  County Code  \
# 0                26 BROAD STREET     ALBANY    NY  12202-0000            1
# 1     115 MAIN STREET PO BOX 642   ALTAMONT    NY       12009            1
# ...

# %%
P2_df = P1_df.dropna()
P2_df

#Export CSV 
P2_df.to_csv('C:/Users/19739/Desktop/New folder/Project_4/Exported Data/FD_List_EXP.csv')
# Out:
#                  Fire Department Name  Fire Department Code  \
# 0              ALBANY FIRE DEPARTMENT                  1001
# 1            ALTAMONT FIRE DEPARTMENT                  1002
# 2               BERNE FIRE DEPARTMENT                  1003
# 3     BOGHT COMMUNITY FIRE DEPARTMENT                  1004
# 4            COEYMANS FIRE DEPARTMENT                  1005
# ...                               ...                   ...
# 1768           HIMROD FIRE DEPARTMENT                 62006
# 1769           MIDDLESEX HOSE COMPANY                 62008
# 1770         PENN YAN FIRE DEPARTMENT                 62009
# 1771           POTTER FIRE DEPARTMENT                 62010
# 1772           RUSHVILLE HOSE COMPANY                 62011
#
#                          Address       City State    Zip Code  County Code  \
# 0                26 BROAD STREET     ALBANY    NY  12202-0000            1
# 1     115 MAIN STREET PO BOX 642   ALTAMONT    NY       12009            1
# ...

# %%
#Export CSV 
P2_df.to_csv('C:/Users/19739/Desktop/New folder/Project_4/Exported Data/FD_List_EXP.csv')

# %%
county = P2_df["County Code"].astype(float)
maxdensity = county.max()
locations = P2_df[["Latitude", "Longitude"]]

# %%
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=county,dissipating=False, max_intensity=maxdensity,point_radius=3)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Phone Number</dt><dd>{Phone Number}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
FD_info = [info_box_template.format(**row) for index, row in P2_df.iterrows()]
locations = P2_df[["Latitude", "Longitude"]]

# %%
# Add marker layer and info box content ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = FD_info)

# Add the layer to the map
fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests 
import os

import json

# %%
FD_df = pd.read_csv("C:/Users/19739/Desktop/New folder/Project_4/Resources/Fatalities.csv")
FD_df
# Out:
#      First Name    Last Name Age                     Rank Classification  \
# 0        Robert      Pollard  64              Firefighter      Volunteer
# 1           Lee        Purdy  57  Pump Operator/Inspector      Volunteer
# 2        Ronald      Osadacz  36    First Assistant Chief      Volunteer
# 3         Allen     Streeter  58              Firefighter      Volunteer
# 4          Gary  Bankert, Sr  37              Firefighter      Volunteer
# ...         ...          ...  ..                      ...            ...
# 2000       Jack         Rose  19                  Captain      Volunteer
# 2001      Stacy     Crawford  47              Firefighter      Volunteer
# 2002     Willie      Ratliff  66                  Captain         Career
# 2003      Louis        Patti  67      Fire Police Officer      Volunteer
# 2004    Patrick    Wolterman  28              Firefighter         Career
#
#      Date of Incident Date of Death       Cause Of Death Nature Of Death  \
# 0           31-Dec-99      1-Jan-00  Stress/Overexertion          Stroke
# 1            8-Jan-00      8-Jan-00  Stress/Overexertion    Heart Attack
# 2           11-Jan-00     11-Jan-00  Stress/Overexertion    Heart Attack
# 3           11-Jan-00     11-Jan-00  Stress/Overexertion    Heart Attack
# 4           15-Jan-00     15-Jan-00              Trapped     Suffocation
# ...               ...           ...                  ...             ...
# 2000        19-Dec-15     19-Dec-15       Disorientation     Suffocation
# 2001        19-Dec-15     19-Dec-15  Stress/Overexertion    Heart Attack
# 2002        21-Dec-15     21-Dec-15  Stress/Overexertion    Heart Attack
# 2003         6-Dec-15     22-Dec-15  Stress/Overexertion          Stroke
# 2004        28-Dec-15     28-Dec-15             Collapse     Suffocation
#
#                Duty                        Activity Emergency  \
# 0          Response               Vehicle Passenger       Yes
# 1     On-Scene Fire  Advance Hose Lines/Fire Attack       Yes
# 2          Response  Advance Hose Lines/Fire Attack       Yes
# 3     On-Scene Fire  Advance Hose Lines/Fire Attack       Yes
# 4          Training                           Other        No
# ...             ...                             ...       ...
# 2000  On-Scene Fire  Advance Hose Lines/Fire Attack       Yes
# 2001       Training                    Not on Scene        No
# 2002        On-Duty                    Not on Scene        No
# 2003        On-Duty                    Not on Scene        No
# 2004  On-Scene Fire  Advance Hose Lines/Fire Attack       Yes
#
#          Property Type Unnamed: 13
# 0     Outdoor Property         NaN
# 1          Residential         NaN
# 2          Street/Road         NaN
# 3     Outdoor Property         NaN
# 4                  NaN         NaN
# ...                ...         ...
# 2000       Residential         NaN
# 2001               NaN         NaN
# 2002               NaN         NaN
# 2003               NaN         NaN
# 2004       Residential         NaN
#
# [2005 rows x 14 columns]

# %%
#Drop 9/11 values 
# get names of indexes for which
# column Age has value 21
index_names = FD_df[ FD_df['Date of Death'] == '11-Sep-01' ].index
  
# drop these row indexes
# from dataFrame
FD_df.drop(index_names, inplace = True)
FD_df




#CD_df = FD_df[['Last Name', 'Cause Of Death']]
#CD_df



#df_micetested_gender = df_clean[['Sex','Mouse ID']] 
#num_micetested_gender  = df_micetested_gender.groupby("Sex").nunique() 
#percentage_gender = ((num_micetested_gender / num_mice_clean)).round(3)
#df_percentage_gender = pd.DataFrame(percentage_gender)
#df_percentage_gender = pd.DataFrame(df_percentage_gender['Mouse ID'])
#df_percentage_gender = df_percentage_gender.rename(columns = {'Mouse ID': '%'})

#df_micetested_gender = pd.DataFrame(num_micetested_gender)
#df_micetested_gender = pd.DataFrame(df_micetested_gender['Mouse ID'])

#df_micetested_gender = df_micetested_gender.rename(columns = {'Mouse ID': 'Count'})


#df_micetested_gender_and_percent = pd.concat([df_micetested_gender, df_percentage_gender], axis=1)
#df_micetested_gender_and_percent
# Out:
#      First Name    Last Name Age                     Rank Classification  \
# 0        Robert      Pollard  64              Firefighter      Volunteer
# 1           Lee        Purdy  57  Pump Operator/Inspector      Volunteer
# 2        Ronald      Osadacz  36    First Assistant Chief      Volunteer
# 3         Allen     Streeter  58              Firefighter      Volunteer
# 4          Gary  Bankert, Sr  37              Firefighter      Volunteer
# ...         ...          ...  ..                      ...            ...
# 2000       Jack         Rose  19                  Captain      Volunteer
# 2001      Stacy     Crawford  47              Firefighter      Volunteer
# 2002     Willie      Ratliff  66                  Captain         Career
# 2003      Louis        Patti  67      Fire Police Officer      Volunteer
# 2004    Patrick    Wolterman  28              Firefighter         Career
#
#      Date of Incident Date of Death       Cause Of Death Nature Of Death  \
# 0           31-Dec-99      1-Jan-00  Stress/Overexertion          Stroke
# 1            8-Jan-00      8-Jan-00  Stress/Overexertion    Heart Attack
# 2           11-Jan-00     11-Jan-00  Stress/Overexertion    Heart Attack
# 3           11-Jan-00     11-Jan-00  Stress/Overexertion    Heart Attack
# 4           15-Jan-00     15-Jan-00              Trapped     Suffocation
# ...               ...           ...                  ...             ...
# 2000        19-Dec-15     19-Dec-15       Disorientation     Suffocation
# 2001        19-Dec-15     19-Dec-15  Stress/Overexertion    Heart Attack
# 2002        21-Dec-15     21-Dec-15  Stress/Overexertion    Heart Attack
# 2003         6-Dec-15     22-Dec-15  Stress/Overexertion          Stroke
# 2004        28-Dec-15     28-Dec-15             Collapse     Suffocation
#
#                Duty                        Activity Emergency  \
# 0          Response               Vehicle Passenger       Yes
# 1     On-Scene Fire  Advance Hose Lines/Fire Attack       Yes
# 2          Response  Advance Hose Lines/Fire Attack       Yes
# 3     On-Scene Fire  Advance Hose Lines/Fire Attack       Yes
# 4          Training                           Other        No
# ...             ...                             ...       ...
# 2000  On-Scene Fire  Advance Hose Lines/Fire Attack       Yes
# 2001       Training                    Not on Scene        No
# 2002        On-Duty                    Not on Scene        No
# 2003        On-Duty                    Not on Scene        No
# 2004  On-Scene Fire  Advance Hose Lines/Fire Attack       Yes
#
#          Property Type Unnamed: 13
# 0     Outdoor Property         NaN
# 1          Residential         NaN
# 2          Street/Road         NaN
# 3     Outdoor Property         NaN
# 4                  NaN         NaN
# ...                ...         ...
# 2000       Residential         NaN
# 2001               NaN         NaN
# 2002               NaN         NaN
# 2003               NaN         NaN
# 2004       Residential         NaN
#
# [1662 rows x 14 columns]

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

plot = df_micetested_gender.plot.pie(subplots=True, autopct="%1.1f%%", title ="Mice Tested by Gender", figsize=(11, 6))
